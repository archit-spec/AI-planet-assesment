# %%
# !wandb login 24634f3c674c87a9
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
inp = """
Sure, here’s a detailed essay on cats:

---

**The Fascinating World of Cats: A Comprehensive Exploration**

Cats have been cherished companions to humans for thousands of years. Their enigmatic nature, diverse personalities, and unique behaviors make them one of the most beloved pets worldwide. This essay delves into the history, behavior, physical characteristics, and cultural significance of cats, offering a comprehensive exploration of these fascinating animals.

**Historical Background**

The domestic cat, *Felis catus*, has a rich history intertwined with human civilization. The domestication of cats is believed to have begun around 4,000 years ago in ancient Egypt. Cats were initially drawn to human settlements due to the abundance of rodents attracted by stored grains. Over time, this mutually beneficial relationship evolved into a deeper bond. The ancient Egyptians revered cats, and they were often depicted in art and mythology. Bastet, the Egyptian goddess of home, fertility, and protection, was represented with the head of a lioness or a domestic cat.

Cats spread from Egypt to other parts of the world through trade and exploration. By the time of the Roman Empire, cats had reached Europe, where they were valued for their pest control abilities. During the Middle Ages, however, cats faced periods of persecution, often associated with superstitions and witchcraft. It wasn't until the Renaissance that cats began to be appreciated once again, and their status as cherished companions was restored.

**Physical Characteristics**

Cats are known for their elegant and agile physiques. An average domestic cat weighs between 5 to 20 pounds and stands about 9 to 10 inches tall at the shoulder. Their bodies are covered in fur, which can vary widely in color, pattern, and length. Some common coat patterns include tabby, calico, and solid colors. Fur length can range from short to long, depending on the breed.

One of the most remarkable features of cats is their exceptional agility. Cats possess a flexible spine and powerful hind leg muscles, enabling them to make high jumps and swift movements. Their retractable claws provide them with a versatile tool for climbing, hunting, and self-defense. Additionally, cats have keen senses: their acute hearing, sharp vision, and sensitive whiskers contribute to their prowess as hunters.

**Behavioral Traits**

Cats are known for their independent nature, but they also exhibit a range of behaviors that reflect their social and environmental interactions. One of the most notable behaviors is grooming. Cats spend a significant portion of their day grooming themselves, which serves multiple purposes, including cleaning their fur, regulating body temperature, and reducing stress.

Social behavior in cats can vary widely. While some cats are highly sociable and enjoy interaction with humans and other animals, others may be more solitary. Domestic cats are territorial animals, and they often mark their territory through scent marking and scratching. Despite their reputation for independence, many cats form strong bonds with their human companions and exhibit affectionate behaviors such as purring, kneading, and head-butting.

Cats are also known for their playful behavior. Play is an essential part of a cat's development and well-being. It helps them hone their hunting skills, provides mental stimulation, and allows them to express their natural instincts. Toys that mimic prey, such as feather wands or laser pointers, can provide hours of entertainment and exercise for cats.

**Communication**

Cats communicate through a combination of vocalizations, body language, and scent marking. Vocalizations include meowing, purring, hissing, and growling. Each sound serves a different purpose: meowing is often used to communicate with humans, while purring generally signifies contentment or relaxation. Hissing and growling are signs of discomfort or aggression.

Body language is another crucial aspect of feline communication. Cats use their tails, ears, and facial expressions to convey their emotions. For example, a cat with its tail upright and ears forward is typically feeling confident and content, while a cat with its tail puffed up and ears back may be frightened or agitated. Understanding these subtle cues can help human companions better interpret their cat's needs and feelings.

Scent marking is an important aspect of feline communication and territory establishment. Cats have scent glands located on their face, paws, and tail, and they use these to mark their territory and communicate with other cats. Scratching is a common behavior associated with scent marking, and it also helps cats maintain their claws.

**Cultural Significance**

Cats have played significant roles in various cultures throughout history. In ancient Egypt, as mentioned earlier, cats were revered and often mummified as part of religious practices. In Japan, the "Maneki-neko," or beckoning cat, is a common talisman believed to bring good luck and prosperity. The image of a cat raising its paw is often displayed in homes and businesses to attract positive energy.

In literature and popular culture, cats have been portrayed in numerous ways. From the enigmatic Cheshire Cat in Lewis Carroll's "Alice's Adventures in Wonderland" to the mischievous Puss in Boots, cats have captured the imaginations of writers and artists. The internet age has further amplified their cultural presence, with countless memes, videos, and social media accounts dedicated to showcasing the quirky and endearing behaviors of cats.

**Cats in Modern Society**

Today, cats are among the most popular pets globally. Their adaptability to indoor living and relatively low-maintenance care requirements make them ideal companions for many people. Cats contribute positively to human well-being, providing emotional support and companionship. Studies have shown that interacting with cats can reduce stress and lower blood pressure.

In addition to being pets, cats also play roles in various professional settings. Therapy cats are trained to provide comfort and emotional support to individuals in hospitals, nursing homes, and other care facilities. Cats are also employed in some workplaces for their pest control abilities, particularly in warehouses and farms.

**Conclusion**

Cats are remarkable creatures with a rich history and diverse characteristics. Their journey from ancient Egypt to modern society highlights their enduring bond with humans. Understanding their behavior, physical traits, and cultural significance allows us to appreciate these animals more deeply. Whether as playful companions or symbols of good fortune, cats continue to capture our hearts and imaginations, solidifying their place as cherished members of our lives.

---

I hope this essay provides a comprehensive overview of cats and their significance! If you need more details on any specific aspect, feel free to ask.

"""

# %%
# %%writefile config.json
# {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 8192,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 8192,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "vocab_size": 50257
# }
# Out:
# Overwriting config.json

# %%
# !pip install rotary_embedding_torch

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config
from rotary_embedding_torch import RotaryEmbedding
from transformers.models.gpt2.modeling_gpt2 import GPT2Attention, GPT2Model

# Check if a GPU is available and use it
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class RotaryGPT2Attention(GPT2Attention):
    def __init__(self, config, is_cross_attention=False, layer_idx=None):
        super().__init__(config, is_cross_attention, layer_idx)
        self.rotary_emb = RotaryEmbedding(dim=config.n_embd // config.n_head, use_xpos=True)

    def _attn(self, query, key, value, attention_mask=None, head_mask=None):
        # Apply rotary embeddings with XPos
        query, key = self.rotary_emb.rotate_queries_and_keys(query, key)
        
        # Continue with the original attention mechanism
        attn_weights = torch.matmul(query, key.transpose(-1, -2))
        if attention_mask is not None:
            attn_weights = attn_weights + attention_mask
        attn_weights = torch.nn.functional.softmax(attn_weights, dim=-1)
        if head_mask is not None:
            attn_weights = attn_weights * head_mask
        attn_output = torch.matmul(attn_weights, value)
        return attn_output, attn_weights

class ModifiedGPT2Model(GPT2Model):
    def __init__(self, config):
        super().__init__(config)
        self.wpe = torch.nn.Embedding(config.n_positions, config.hidden_size)
        self.h = torch.nn.ModuleList([RotaryGPT2Attention(config) for _ in range(config.n_layer)])
        self.init_weights()

# Load tokenizer and config
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
config = GPT2Config.from_pretrained("config.json")
config.n_positions = 8192  # Update max_position_embeddings

# Instantiate the modified model
model = GPT2LMHeadModel(config)
model.transformer = ModifiedGPT2Model(config)

# Move the model to GPU
model.to(device)

# Example usage
input_text = "Example text to test the modified model."
input_ids = tokenizer.encode(inp, return_tensors='pt').to(device)

# Generate output
outputs = model.generate(input_ids, max_length=3500)  # Adjust max_length as needed

# Decode generated output
decoded_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded_output)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1369 > 1024). Running this sequence through the model will result in indexing errors
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sure, here’s a detailed essay on cats:
#
# ---
#
# **The Fascinating World of Cats: A Comprehensive Exploration**
#
# Cats have been cherished companions to humans for thousands of years. Their enigmatic nature, diverse personalities, and unique behaviors make them one of the most beloved pets worldwide. This essay delves into the history, behavior, physical characteristics, and cultural significance of cats, offering a comprehensive exploration of these fascinating animals.
#
# **Historical Background**
#
# ...

# %%
import os

# Define the directory where you want to save the model
model_dir = "model"

# Save the model and tokenizer
model.save_pretrained(model_dir)
tokenizer.save_pretrained(model_dir)

print(f"Model saved to {model_dir}")
# Out:
# Model saved to model

# %%
from huggingface_hub import login

login(token="hf_xqncwGGslWE")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !rm -rf model
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Save your model and tokenizer
model_dir = "./GPT2LONG"

tokenizer.save_pretrained(model_dir)
model.save_pretrained(model_dir)

# %%
trainer.model.push_to_hub("archit11/GPT2")
# Out:
# model.safetensors:   0%|          | 0.00/447M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/archit11/GPT2/commit/1faf44366d7399b55033749190fe89fe43a08da6', commit_message='Upload model', commit_description='', oid='1faf44366d7399b55033749190fe89fe43a08da6', pr_url=None, pr_revision=None, pr_num=None)

# %%
from huggingface_hub import HfApi, HfFolder, Repository
import os

# Define your repository name and local directory
repo_name = "archit11/GPT2"
model_dir = "./GPT2LONG"

# Get your Hugging Face token
token = HfFolder.get_token()

# Create the repository if it doesn't exist
api = HfApi()
api.create_repo(repo_id=repo_name, repo_type="model", private=False, token=token)

# Initialize the repository
repo = Repository(local_dir=model_dir, clone_from=repo_name, use_auth_token=token)

# Add and commit the files
repo.git_add(auto_lfs_track=True)
repo.git_commit("Initial commit")

# Push the files to the Hub
repo.git_push()
# Out:
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[84], line 16
#      13 api.create_repo(repo_id=repo_name, repo_type="model", private=False, token=token)
#      15 # Initialize the repository
# ---> 16 repo = Repository(local_dir=model_dir, clone_from=repo_name, use_auth_token=token)
#      18 # Add and commit the files
#      19 repo.git_add(auto_lfs_track=True)
#
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("akoksal/LongForm",split='train[:10%]')

# %%
def tokenize_function(examples):
    # Combine input and output into a single string
    prompts = [f"<|endoftext|>Human: {input}\nAssistant: {output}<|endoftext|>" for input, output in zip(examples['input'], examples['output'])]
    
    return tokenizer(prompts, truncation=True, padding=False, max_length=4096)

# %%
tokenized_datasets = dataset.map(tokenize_function, batched=True, remove_columns=dataset.column_names)

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': tokenizer.eos_token})

# %%
from transformers import Trainer, TrainingArguments

# Define training arguments
training_args = TrainingArguments(
    output_dir="results",
    num_train_epochs=1,
    per_device_train_batch_size=1,  # Adjust based on your GPU memory
    per_device_eval_batch_size=1,
    evaluation_strategy="steps",
    save_steps=1000,
    warmup_steps=50,
    weight_decay=0.01,
    logging_dir='./logs',
    fp16=False,  # If your GPU supports it
    gradient_accumulation_steps=1,  # Adjust as needed
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["input_ids"],
    data_collator=data_collator

)

# Start training
trainer.train()

# %%
input_ids = tokenizer.encode(inp, return_tensors='pt').to(device)

# Generate output
outputs = model.generate(input_ids, max_length=3500)  # Adjust max_length as needed

# Decode generated output
decoded_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded_output)
